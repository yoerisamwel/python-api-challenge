# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
#import geopandas as gpd


# Import API key
from api_keys import geoaypify_key
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0          grytviken -54.2811  -36.5092      2.46        81
# 1        1           waitangi -43.9535 -176.5597      7.68        75
# 2        2      cockburn town  21.4612  -71.1419     29.42        77
# 3        3         georgetown   5.4112  100.3354     27.96        87
# 4        4  port-aux-francais -49.3500   70.2167      5.01        96
#
#    Cloudiness  Wind Speed Country        Date
# 0          11        6.19      GS  1696778305
# 1         100        6.50      NZ  1696778305
# 2          36        5.98      TC  1696778305
# 3          40        3.09      MY  1696778259
# 4         100       19.73      TF  1696778305

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_df.hvplot.points('Lng', 'Lat', geo=True, color="Humidity", 
                               size="Humidity", frame_height=500, 
                               frame_width=700,tiles='OSM', title="City data with Humidity")
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
city_data_df = city_data_df.dropna()

city_data_df = city_data_df[city_data_df['Max Temp'] >= 25]
city_data_df = city_data_df[city_data_df['Max Temp'] < 30]
city_data_df = city_data_df[city_data_df['Cloudiness'] < 30]
city_data_df = city_data_df[city_data_df['Humidity'] < 70]

# Display sample data
city_data_df
# Out:
#      City_ID                           City      Lat       Lng  Max Temp  \
# 42        42                       vallenar -28.5708  -70.7581     26.55
# 51        51                     manoharpur  27.3000   75.9500     28.20
# 74        74                            sur  22.5667   59.5289     29.76
# 78        78                       karratha -20.7377  116.8463     26.22
# 114      114                          lahij  13.1667   44.5833     29.99
# 115      115                           ghat  24.9647   10.1728     29.45
# 164      164                         barika  35.3890    5.3658     27.51
# 167      167                general levalle -34.0147  -63.9241     29.79
# 176      176                arraial do cabo -22.9661  -42.0278     29.98
# 181      181  ingeniero guillermo n. juarez -23.9000  -61.8500     29.73
# 238      238                          dausa  26.8833   76.3333     29.46
# 242      242                      kavaratti  10.5669   72.6420     27.73
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = city_data_df[['City','Humidity','Country','Lat','Lng']].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df['Hotel Name'] = ''

# Display sample data
hotel_df
# Out:
#                               City  Humidity Country      Lat       Lng  \
# 42                        vallenar        19      CL -28.5708  -70.7581
# 51                      manoharpur        41      IN  27.3000   75.9500
# 74                             sur        64      OM  22.5667   59.5289
# 78                        karratha        56      AU -20.7377  116.8463
# 114                          lahij        50      YE  13.1667   44.5833
# 115                           ghat        17      LY  24.9647   10.1728
# 164                         barika        31      DZ  35.3890    5.3658
# 167                general levalle        14      AR -34.0147  -63.9241
# 176                arraial do cabo        66      BR -22.9661  -42.0278
# 181  ingeniero guillermo n. juarez        24      AR -23.9000  -61.8500
# 238                          dausa        39      IN  26.8833   76.3333
# 242                      kavaratti        63      IN  10.5669   72.6420
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000 
params = {"categories": "accommodation.hotel",
          "apiKey":geoaypify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    longitude = row["Lng"]
    latitude = row["Lat"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params = params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# vallenar - nearest hotel: Hotel del Marqués
# manoharpur - nearest hotel: Alila Fort Bishangarh
# sur - nearest hotel: Sur Hotel
# karratha - nearest hotel: Karratha International Hotel
# lahij - nearest hotel: No hotel found
# ghat - nearest hotel: فندق تاسيلي
# barika - nearest hotel: فندق ميساوي
# general levalle - nearest hotel: Hostal Del Lago
# arraial do cabo - nearest hotel: No hotel found
# ingeniero guillermo n. juarez - nearest hotel: Hotel El Indiano
# dausa - nearest hotel: No hotel found
# kavaratti - nearest hotel: No hotel found
# keren - nearest hotel: Eritrea Hotel قندق إرتريا
# tsiombe - nearest hotel: No hotel found
# itamaraca - nearest hotel: No hotel found
# tabas - nearest hotel: هتل امیر
# calatayud - nearest hotel: Arco San Miguel
# dwarka - nearest hotel: The Dwarika Hotel
# sitangkai - nearest hotel: No hotel found
# villa de soto - nearest hotel: La Eleida
# markaz-e woluswali-ye achin - nearest hotel: No hotel found
# ...

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

hotel_map_incl_names = hotel_df.hvplot.points("Lng", "Lat", geo = True, color = "City",
                        alpha = 0.9, size = "Humidity",  tiles = "ESRI", hover_cols = ["Hotel Name", "Country"]
                                  )
hotel_map_incl_names
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
