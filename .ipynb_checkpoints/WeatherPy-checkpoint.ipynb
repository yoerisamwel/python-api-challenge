# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 610

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?units=Metric&APPID=" + weather_api_key

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    #print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          594
# Lat           594
# Lng           594
# Max Temp      594
# Humidity      594
# Cloudiness    594
# Wind Speed    594
# Country       594
# Date          594
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  alice springs -23.7000  133.8833     12.75        22           0
# 1       zaragoza  41.6561   -0.8773     25.01        41          20
# 2        talnakh  69.4865   88.3972      0.67        93          99
# 3       ust-nera  64.5667  143.2000    -15.99        95          95
# 4          tiksi  71.6872  128.8694     -9.36        94         100
#
#    Wind Speed Country        Date
# 0        0.00      AU  1697296246
# 1        3.60      ES  1697296367
# 2        3.41      RU  1697296367
# 3        0.89      RU  1697296367
# 4        3.78      RU  1697296368

# %%
# Export the City_Data into a csv
city_data_df.to_csv("cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        alice springs -23.7000  133.8833     12.75        22           0
# 1             zaragoza  41.6561   -0.8773     25.01        41          20
# 2              talnakh  69.4865   88.3972      0.67        93          99
# 3             ust-nera  64.5667  143.2000    -15.99        95          95
# 4                tiksi  71.6872  128.8694     -9.36        94         100
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      AU  1697296246
# 1              3.60      ES  1697296367
# 2              3.41      RU  1697296367
# 3              0.89      RU  1697296367
# 4              3.78      RU  1697296368

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Max Temp", y="Lat", grid=True, figsize=(8,8),
              title="latitude vs. temperature")
# Incorporate the other graph properties
plt.xlabel("Max Temperature (C)")
plt.ylabel("Latitude")

# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Humidity", y="Lat", grid=True, figsize=(8,8),
              title="City Latitude vs. Humidity (10/7/2023)")
# Incorporate the other graph properties
plt.xlabel("Humidity (%)")
plt.ylabel("Latitude")

# Save the figure
#plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Cloudiness", y="Lat", grid=True, figsize=(8,8),
              title="City Latitude vs. Cloudiness (10/7/2023)")
# Incorporate the other graph properties
plt.xlabel("Cloudiness (%)")
plt.ylabel("Latitude")

# Save the figure
#plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Wind Speed", y="Lat", grid=True, figsize=(8,8),
              title="City Latitude vs. Wind Speed (10/7/2023)")
# Incorporate the other graph properties
plt.xlabel("Wind Speed (m/s)")
plt.ylabel("Latitude")

# Save the figure
#plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regression_plot (a,b):
    slope, intc, r, p, std_err = linregress(a, b)
    model=slope*a+intc
    plt.scatter(a, b)
    plt.plot(a, model, color='red')
    return plt

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          zaragoza  41.6561   -0.8773     25.01        41          20
# 2           talnakh  69.4865   88.3972      0.67        93          99
# 3          ust-nera  64.5667  143.2000    -15.99        95          95
# 4             tiksi  71.6872  128.8694     -9.36        94         100
# 5        port blair  11.6667   92.7500     27.42        80          95
#
#          Wind Speed Country        Date
# City_ID
# 1              3.60      ES  1697296367
# 2              3.41      RU  1697296367
# 3              0.89      RU  1697296367
# 4              3.78      RU  1697296368
# 5              1.80      IN  1697296368

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        alice springs -23.7000  133.8833     12.75        22           0
# 6              santana  -0.0583  -51.1817     32.10        62          20
# 7               avarua -21.2078 -159.7750     21.03        88          33
# 8             waitangi -43.9535 -176.5597     12.68        93           5
# 13               papao -17.7500 -149.5500     22.82        73          74
#
#          Wind Speed Country        Date
# City_ID
# 0              0.00      AU  1697296246
# 6              4.63      BR  1697296368
# 7              1.03      CK  1697296140
# 8              2.68      NZ  1697296368
# 13             5.90      PF  1697296368

# %%
#slope, intc, r, p, std_err = linregress(northern_hemi_df['Max Temp'], northern_hemi_df['Lat'])
#model=slope*northern_hemi_df["Max Temp"]+intc
#plt.scatter(northern_hemi_df["Max Temp"], northern_hemi_df["Lat"])
#plt.plot(northern_hemi_df["Max Temp"], model, color='red')

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
plot_nh = linear_regression_plot (northern_hemi_df['Max Temp'],northern_hemi_df['Lat'])
plot_nh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Linear regression on Southern Hemisphere
plot_sh = linear_regression_plot (southern_hemi_df['Max Temp'],southern_hemi_df['Lat'])
plot_sh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_nh = linear_regression_plot (northern_hemi_df['Humidity'],northern_hemi_df['Lat'])
plot_nh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Southern Hemisphere
plot_sh = linear_regression_plot (southern_hemi_df['Humidity'],southern_hemi_df['Lat'])
plot_sh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_nh = linear_regression_plot (northern_hemi_df['Cloudiness'],northern_hemi_df['Lat'])
plot_nh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Southern Hemisphere
plot_sh = linear_regression_plot (southern_hemi_df['Cloudiness'],southern_hemi_df['Lat'])
plot_sh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
plot_nh = linear_regression_plot (northern_hemi_df['Wind Speed'],northern_hemi_df['Lat'])
plot_nh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
# Southern Hemisphere
plot_sh = linear_regression_plot (southern_hemi_df['Wind Speed'],southern_hemi_df['Lat'])
plot_sh
# Out:
# <module 'matplotlib.pyplot' from 'C:\\Users\\yoeri\\anaconda3\\Lib\\site-packages\\matplotlib\\pyplot.py'>

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %%
'''
For the latitude and temperature regression plot I can see a clear correlation 
between the latitude and the maximum temperature. For the humidity, wind and cloudiness 
comparisons the correlation does not seem strong to me.
'''
# Out:
# '\nFor the latitude and temperature regression plot I can see a clear correlation \nbetween the latitude and the maximum temperature. For the humidity, wind and cloudiness \ncomparisons the correlation does not seem strong to me.\n'
